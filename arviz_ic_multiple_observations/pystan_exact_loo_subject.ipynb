# %%
import arviz as az
import numpy as np

from generate_data import generate_data
from utils import StanModel_cache

# %%
n = 100
Years_indiv, Mean_RT_comp_Indiv, Mean_RT_incomp_Indiv = generate_data(8, n)
dims = {"y_obs_comp": ["subject"], "y_obs_incomp": ["subject"]}
log_lik_dict = ["log_lik", "log_lik_ex"]
data = {
    "n": n,
    "y_obs_comp": Mean_RT_comp_Indiv,
    "y_obs_incomp": Mean_RT_incomp_Indiv,
    "age": Years_indiv,
    "mean_rt_c": Mean_RT_comp_Indiv.mean(),
    "mean_rt_i": Mean_RT_incomp_Indiv.mean(),
    "n_ex": 0,
    "age_ex": np.array([], dtype=int),
    "y_obs_comp_ex": [],
    "y_obs_incomp_ex": [],
}

# %% [markdown]
# This code is basically the same as the one in the PyStan example (and also equivalent to the PyMC3 one) with two main differences:
# * The log likelihood returned is already the sum of the 2 observations that correspond to each subject
# * There are also some variable with a `_ex` sufix. These variables will be used to perform exact cross validation, they indicate the data that is not used for fitting but for cross validation.

# %%
loo_subject_code = """
data {
    int<lower=0> n;
    real y_obs_comp[n];
    real y_obs_incomp[n];
    int<lower=0> age[n];
    real mean_rt_c;
    real mean_rt_i;
    // excluded data
    int<lower=0> n_ex;
    real y_obs_comp_ex[n_ex];
    real y_obs_incomp_ex[n_ex];
    int<lower=0> age_ex[n_ex];
}

parameters {
    real b;
    real<lower=0> sigma;
    real<lower=0> a_c;
    real<lower=0> a_i;
    real g_c;
    real g_i;
}

transformed parameters {
    real mu_c[n];
    real mu_i[n];
    real mu_c_ex[n_ex];
    real mu_i_ex[n_ex];

    for (j in 1:n) {
        mu_c[j] = a_c*exp(-b*age[j]) + g_c;
        mu_i[j] = a_i*exp(-b*age[j]) + g_i;
    }
    for (i in 1:n_ex) {
        mu_c_ex[i] = a_c*exp(-b*age_ex[i]) + g_c;
        mu_i_ex[i] = a_i*exp(-b*age_ex[i]) + g_i;
    }
}

model {
    a_c ~ cauchy(0, 5);
    a_i ~ cauchy(0, 5);
    b ~ normal(1, 1);
    g_c ~ normal(mean_rt_c, .5);
    g_i ~ normal(mean_rt_i, .5);
    sigma ~ normal(0, .2);
    y_obs_comp ~ normal(mu_c, sigma);
    y_obs_incomp ~ normal(mu_i, sigma);
}

generated quantities {
    real log_lik[n];
    real log_lik_ex[n_ex];

    for (j in 1:n) {
        log_lik[j] = normal_lpdf(y_obs_comp[j] | mu_c[j], sigma) + normal_lpdf(y_obs_incomp[j] | mu_i[j], sigma);
    }
    for (i in 1:n_ex) {
        log_lik_ex[i] = normal_lpdf(y_obs_comp_ex[i] | mu_c_ex[i], sigma) + normal_lpdf(y_obs_incomp_ex[i] | mu_i_ex[i], sigma);
    }
}
"""

# %%
stan_model = StanModel_cache(model_code=loo_subject_code)
fit_kwargs = dict(iter=4000, control={"adapt_delta" : 0.9})
fit = stan_model.sampling(data=data, **fit_kwargs)
# Out:
# Using cached StanModel
# WARNING:pystan:89 of 8000 iterations ended with a divergence (1.11 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.

# %%
idata_kwargs = dict(
    observed_data=["y_obs_comp", "y_obs_incomp"],
    constant_data=["age"],
    dims=dims,
    log_likelihood=log_lik_dict
)
idata_exp = az.from_pystan(fit, **idata_kwargs)

# %%
class ExpWrapper(az.PyStanSamplingWrapper):

    def sel_observations(self, idx):
        age = self.idata_orig.constant_data.age.values
        y_c = self.idata_orig.observed_data.y_obs_comp.values
        y_i = self.idata_orig.observed_data.y_obs_incomp.values
        mask = np.full_like(age, True, dtype=bool)
        mask[idx] = False
        n_obs = np.sum(mask)
        n_ex = np.sum(~mask)
        observations = {
            "n": n_obs,
            "age": age[mask],
            "y_obs_comp": y_c[mask],
            "y_obs_incomp": y_i[mask],
            "mean_rt_c": y_c[mask].mean(),
            "mean_rt_i": y_i[mask].mean(),
            "n_ex": n_ex,
            "age_ex": age[~mask],
            "y_obs_comp_ex": y_c[~mask],
            "y_obs_incomp_ex": y_i[~mask]
        }
        return observations, "log_lik_ex"

# %%
idata_exp.sample_stats["log_likelihood"] = idata_exp.log_likelihood.log_lik
loo_psis = az.loo(idata_exp, pointwise=True)
print("(PSIS) Leave one *subject* out cross validation (whole model)\n")
loo_psis
# Out:
# (PSIS) Leave one *subject* out cross validation (whole model)
# Computed from 8000 by 100 log-likelihood matrix
#
#          Estimate       SE
# elpd_loo  -296.90    10.12
# p_loo        3.74        -
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)      100  100.0%
#  (0.5, 0.7]   (ok)          0    0.0%
#    (0.7, 1]   (bad)         0    0.0%
#    (1, Inf)   (very bad)    0    0.0%

# %%
loo_psis.pareto_k[:] = 1.2  # dirty trick: we set all pareto_k values above threshold
                            # to make reloo perform exact cross validation for us
exp_wrapper = ExpWrapper(
    stan_model,
    idata_orig=idata_exp,
    sample_kwargs=fit_kwargs,
    idata_kwargs=idata_kwargs
)
loo_exact = az.reloo(exp_wrapper, loo_orig=loo_psis)
# Out:
# /home/oriol/venvs/arviz-dev/lib/python3.6/site-packages/arviz/stats/stats_refitting.py:98: UserWarning: reloo is an experimental and untested feature
#   warnings.warn("reloo is an experimental and untested feature", UserWarning)
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 0
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 0
# WARNING:pystan:209 of 8000 iterations ended with a divergence (2.61 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 1
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 1
# WARNING:pystan:373 of 8000 iterations ended with a divergence (4.66 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 2
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 2
# WARNING:pystan:50 of 8000 iterations ended with a divergence (0.625 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 3
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 3
# WARNING:pystan:30 of 8000 iterations ended with a divergence (0.375 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 4
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 4
# WARNING:pystan:4 of 8000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 5
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 5
# WARNING:pystan:80 of 8000 iterations ended with a divergence (1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 6
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 6
# WARNING:pystan:8 of 8000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 7
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 7
# WARNING:pystan:11 of 8000 iterations ended with a divergence (0.138 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 8
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 8
# WARNING:pystan:22 of 8000 iterations ended with a divergence (0.275 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 9
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 9
# WARNING:pystan:61 of 8000 iterations ended with a divergence (0.762 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 10
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 10
# WARNING:pystan:17 of 8000 iterations ended with a divergence (0.212 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 11
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 11
# WARNING:pystan:22 of 8000 iterations ended with a divergence (0.275 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 12
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 12
# WARNING:pystan:8 of 8000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 13
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 13
# WARNING:pystan:4 of 8000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 14
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 14
# WARNING:pystan:10 of 8000 iterations ended with a divergence (0.125 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 15
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 15
# WARNING:pystan:25 of 8000 iterations ended with a divergence (0.312 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 16
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 16
# WARNING:pystan:67 of 8000 iterations ended with a divergence (0.838 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 17
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 17
# WARNING:pystan:20 of 8000 iterations ended with a divergence (0.25 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 18
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 18
# WARNING:pystan:10 of 8000 iterations ended with a divergence (0.125 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 19
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 19
# WARNING:pystan:5 of 8000 iterations ended with a divergence (0.0625 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 20
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 20
# WARNING:pystan:137 of 8000 iterations ended with a divergence (1.71 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 21
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 21
# WARNING:pystan:7 of 8000 iterations ended with a divergence (0.0875 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 22
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 22
# WARNING:pystan:18 of 8000 iterations ended with a divergence (0.225 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 23
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 23
# WARNING:pystan:8 of 8000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 24
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 24
# WARNING:pystan:30 of 8000 iterations ended with a divergence (0.375 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 25
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 25
# WARNING:pystan:16 of 8000 iterations ended with a divergence (0.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 26
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 26
# WARNING:pystan:5 of 8000 iterations ended with a divergence (0.0625 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 27
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 27
# WARNING:pystan:13 of 8000 iterations ended with a divergence (0.163 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 28
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 28
# WARNING:pystan:148 of 8000 iterations ended with a divergence (1.85 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 29
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 29
# WARNING:pystan:92 of 8000 iterations ended with a divergence (1.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 30
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 30
# WARNING:pystan:15 of 8000 iterations ended with a divergence (0.188 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 31
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 31
# WARNING:pystan:11 of 8000 iterations ended with a divergence (0.138 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 32
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 32
# WARNING:pystan:66 of 8000 iterations ended with a divergence (0.825 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 33
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 33
# WARNING:pystan:44 of 8000 iterations ended with a divergence (0.55 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 34
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 34
# WARNING:pystan:13 of 8000 iterations ended with a divergence (0.163 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 35
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 35
# WARNING:pystan:115 of 8000 iterations ended with a divergence (1.44 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 36
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 36
# WARNING:pystan:3 of 8000 iterations ended with a divergence (0.0375 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 37
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 37
# WARNING:pystan:32 of 8000 iterations ended with a divergence (0.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 38
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 38
# WARNING:pystan:19 of 8000 iterations ended with a divergence (0.237 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 39
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 39
# WARNING:pystan:17 of 8000 iterations ended with a divergence (0.212 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 40
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 40
# WARNING:pystan:104 of 8000 iterations ended with a divergence (1.3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 41
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 41
# WARNING:pystan:117 of 8000 iterations ended with a divergence (1.46 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 42
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 42
# WARNING:pystan:6 of 8000 iterations ended with a divergence (0.075 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 43
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 43
# WARNING:pystan:41 of 8000 iterations ended with a divergence (0.512 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 44
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 44
# WARNING:pystan:38 of 8000 iterations ended with a divergence (0.475 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 45
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 45
# WARNING:pystan:11 of 8000 iterations ended with a divergence (0.138 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 46
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 46
# WARNING:pystan:17 of 8000 iterations ended with a divergence (0.212 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 47
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 47
# WARNING:pystan:51 of 8000 iterations ended with a divergence (0.637 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 48
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 48
# WARNING:pystan:14 of 8000 iterations ended with a divergence (0.175 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 49
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 49
# WARNING:pystan:53 of 8000 iterations ended with a divergence (0.662 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 50
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 50
# WARNING:pystan:35 of 8000 iterations ended with a divergence (0.438 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 51
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 51
# WARNING:pystan:8 of 8000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 52
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 52
# WARNING:pystan:3 of 8000 iterations ended with a divergence (0.0375 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 53
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 53
# WARNING:pystan:11 of 8000 iterations ended with a divergence (0.138 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 54
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 54
# WARNING:pystan:17 of 8000 iterations ended with a divergence (0.212 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 55
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 55
# WARNING:pystan:24 of 8000 iterations ended with a divergence (0.3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 56
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 56
# WARNING:pystan:92 of 8000 iterations ended with a divergence (1.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 57
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 57
# WARNING:pystan:222 of 8000 iterations ended with a divergence (2.77 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 58
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 58
# WARNING:pystan:167 of 8000 iterations ended with a divergence (2.09 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 59
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 59
# WARNING:pystan:5 of 8000 iterations ended with a divergence (0.0625 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 60
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 60
# WARNING:pystan:101 of 8000 iterations ended with a divergence (1.26 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 61
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 61
# WARNING:pystan:13 of 8000 iterations ended with a divergence (0.163 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 62
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 62
# WARNING:pystan:23 of 8000 iterations ended with a divergence (0.287 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 63
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 63
# WARNING:pystan:10 of 8000 iterations ended with a divergence (0.125 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 64
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 64
# WARNING:pystan:2 of 8000 iterations ended with a divergence (0.025 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 65
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 65
# WARNING:pystan:6 of 8000 iterations ended with a divergence (0.075 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 66
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 66
# WARNING:pystan:24 of 8000 iterations ended with a divergence (0.3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 67
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 67
# WARNING:pystan:135 of 8000 iterations ended with a divergence (1.69 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 68
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 68
# WARNING:pystan:14 of 8000 iterations ended with a divergence (0.175 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 69
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 69
# WARNING:pystan:96 of 8000 iterations ended with a divergence (1.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 70
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 70
# WARNING:pystan:1 of 8000 iterations ended with a divergence (0.0125 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 71
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 71
# WARNING:pystan:7 of 8000 iterations ended with a divergence (0.0875 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 72
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 72
# WARNING:pystan:10 of 8000 iterations ended with a divergence (0.125 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 73
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 73
# WARNING:pystan:12 of 8000 iterations ended with a divergence (0.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 74
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 74
# WARNING:pystan:31 of 8000 iterations ended with a divergence (0.388 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 75
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 75
# WARNING:pystan:81 of 8000 iterations ended with a divergence (1.01 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 76
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 76
# WARNING:pystan:22 of 8000 iterations ended with a divergence (0.275 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 77
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 77
# WARNING:pystan:7 of 8000 iterations ended with a divergence (0.0875 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 78
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 78
# WARNING:pystan:16 of 8000 iterations ended with a divergence (0.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 79
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 79
# WARNING:pystan:46 of 8000 iterations ended with a divergence (0.575 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 80
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 80
# WARNING:pystan:8 of 8000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 81
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 81
# WARNING:pystan:10 of 8000 iterations ended with a divergence (0.125 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 82
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 82
# WARNING:pystan:81 of 8000 iterations ended with a divergence (1.01 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 83
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 83
# WARNING:pystan:11 of 8000 iterations ended with a divergence (0.138 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 84
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 84
# WARNING:pystan:23 of 8000 iterations ended with a divergence (0.287 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 85
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 85
# WARNING:pystan:97 of 8000 iterations ended with a divergence (1.21 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 86
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 86
# WARNING:pystan:10 of 8000 iterations ended with a divergence (0.125 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 87
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 87
# WARNING:pystan:60 of 8000 iterations ended with a divergence (0.75 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 88
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 88
# WARNING:pystan:25 of 8000 iterations ended with a divergence (0.312 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 89
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 89
# WARNING:pystan:113 of 8000 iterations ended with a divergence (1.41 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 90
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 90
# WARNING:pystan:133 of 8000 iterations ended with a divergence (1.66 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 91
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 91
# WARNING:pystan:24 of 8000 iterations ended with a divergence (0.3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 92
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 92
# WARNING:pystan:31 of 8000 iterations ended with a divergence (0.388 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 93
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 93
# WARNING:pystan:7 of 8000 iterations ended with a divergence (0.0875 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 94
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 94
# WARNING:pystan:6 of 8000 iterations ended with a divergence (0.075 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 95
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 95
# WARNING:pystan:6 of 8000 iterations ended with a divergence (0.075 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 96
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 96
# WARNING:pystan:20 of 8000 iterations ended with a divergence (0.25 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 97
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 97
# WARNING:pystan:36 of 8000 iterations ended with a divergence (0.45 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 98
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 98
# WARNING:pystan:24 of 8000 iterations ended with a divergence (0.3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 99
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 99
# WARNING:pystan:27 of 8000 iterations ended with a divergence (0.338 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# (exact) Leave one *subject* out cross validation (whole model)
# Computed from 8000 by 100 log-likelihood matrix
#
#          Estimate       SE
# elpd_loo  -296.81    10.09
# p_loo        3.65        -
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)      100  100.0%
#  (0.5, 0.7]   (ok)          0    0.0%
#    (0.7, 1]   (bad)         0    0.0%
#    (1, Inf)   (very bad)    0    0.0%

# %%
print("(exact) Leave one *subject* out cross validation (whole model)\n")
loo_exact
# Out:
# (exact) Leave one *subject* out cross validation (whole model)
# Computed from 8000 by 100 log-likelihood matrix
#
#          Estimate       SE
# elpd_loo  -296.81    10.09
# p_loo        3.65        -
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)      100  100.0%
#  (0.5, 0.7]   (ok)          0    0.0%
#    (0.7, 1]   (bad)         0    0.0%
#    (1, Inf)   (very bad)    0    0.0%
