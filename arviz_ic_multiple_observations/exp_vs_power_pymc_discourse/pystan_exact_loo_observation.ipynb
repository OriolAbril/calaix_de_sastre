# %%
import arviz as az
import numpy as np

from generate_data import generate_data
from utils import StanModel_cache

# %%
n = 100
Years_indiv, Mean_RT_comp_Indiv, Mean_RT_incomp_Indiv = generate_data(8, n)
y_obs = np.hstack((Mean_RT_comp_Indiv, Mean_RT_incomp_Indiv))
age = np.hstack((Years_indiv, Years_indiv))
condition =  np.hstack((np.full(n, 1, dtype=int), np.full(n, 2, dtype=int))) # 1 for comp, 2 for incomp
dims = {"y_obs": ["obs_dim"]}
log_lik_dict = ["log_lik", "log_lik_ex"]
data = {
    "n": 2*n,
    "y_obs": y_obs,
    "condition": condition,
    "age": age,
    "mean_rt": [Mean_RT_comp_Indiv.mean(), Mean_RT_incomp_Indiv.mean()],
    "n_ex": 0,
    "age_ex": np.array([], dtype=int),
    "y_obs_ex": [],
    "condition_ex": np.array([], dtype=int),
}

# %% [markdown]
# This code is basically the same as the one in the PyStan example (and also equivalent to the PyMC3 one) with two main differences:
# * The log likelihood returned is already the sum of the 2 observations that correspond to each subject
# * There are also some variable with a `_ex` sufix. These variables will be used to perform exact cross validation, they indicate the data that is not used for fitting but for cross validation.

# %%
loo_obs_code = """
data {
    int<lower=0> n;
    real y_obs[n];
    int condition[n];
    int<lower=0> age[n];
    real mean_rt[2];
    // excluded data
    int<lower=0> n_ex;
    real y_obs_ex[n_ex];
    int condition_ex[n_ex];
    int<lower=0> age_ex[n_ex];
}

parameters {
    real b;
    real<lower=0> sigma;
    real<lower=0> a[2];
    real g[2];
}

transformed parameters {
    real mu[n];
    real mu_ex[n_ex];

    for (j in 1:n) {
        mu[j] = a[condition[j]]*exp(-b*age[j]) + g[condition[j]];
    }
    for (i in 1:n_ex) {
        mu_ex[i] = a[condition_ex[i]]*exp(-b*age_ex[i]) + g[condition_ex[i]];
    }
}

model {
    a ~ cauchy(0, 5);
    b ~ normal(1, 1);
    g ~ normal(mean_rt, .5);
    sigma ~ normal(0, .2);
    y_obs ~ normal(mu, sigma);
}

generated quantities {
    real log_lik[n];
    real log_lik_ex[n_ex];

    for (j in 1:n) {
        log_lik[j] = normal_lpdf(y_obs[j] | mu[j], sigma);
    }
    for (i in 1:n_ex) {
        log_lik_ex[i] = normal_lpdf(y_obs_ex[i] | mu_ex[i], sigma);
    }
}
"""

# %%
stan_model = StanModel_cache(model_code=loo_obs_code)
fit_kwargs = dict(iter=4000, control={"adapt_delta" : 0.9})
fit = stan_model.sampling(data=data, **fit_kwargs)
# Out:
# Using cached StanModel
# WARNING:pystan:15 of 8000 iterations ended with a divergence (0.188 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.

# %%
idata_kwargs = dict(
    observed_data=["y_obs", "condition"],
    constant_data=["age"],
    dims=dims,
    log_likelihood=log_lik_dict
)
idata_exp = az.from_pystan(fit, **idata_kwargs)

# %%
class ExpWrapper(az.PyStanSamplingWrapper):

    def sel_observations(self, idx):
        ages = self.idata_orig.constant_data.age.values
        y = self.idata_orig.observed_data.y_obs.values
        cond = self.idata_orig.observed_data.condition.values
        mask = np.full_like(ages, True, dtype=bool)
        mask[idx] = False
        n_obs = np.sum(mask)
        n_ex = np.sum(~mask)
        means = [y[mask & cond == 0].mean(), y[mask & cond == 1].mean()]
        observations = {
            "n": n_obs,
            "age": ages[mask],
            "y_obs": y[mask],
            "condition": cond[mask],
            "mean_rt": means,
            "n_ex": n_ex,
            "age_ex": ages[~mask],
            "y_obs_ex": y[~mask],
            "condition_ex": cond[~mask]
        }
        return observations, "log_lik_ex"

# %%
idata_exp.sample_stats["log_likelihood"] = idata_exp.log_likelihood.log_lik
loo_psis = az.loo(idata_exp, pointwise=True)
print("(PSIS) Leave one *subject* out cross validation (whole model)\n")
loo_psis
# Out:
# (PSIS) Leave one *subject* out cross validation (whole model)
# Computed from 8000 by 200 log-likelihood matrix
#
#          Estimate       SE
# elpd_loo  -296.77    10.97
# p_loo        3.69        -
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)      200  100.0%
#  (0.5, 0.7]   (ok)          0    0.0%
#    (0.7, 1]   (bad)         0    0.0%
#    (1, Inf)   (very bad)    0    0.0%

# %%
loo_psis.pareto_k[:] = 1.2  # dirty trick: we set all pareto_k values above threshold
                            # to make reloo perform exact cross validation for us
exp_wrapper = ExpWrapper(
    stan_model,
    idata_orig=idata_exp,
    sample_kwargs=fit_kwargs,
    idata_kwargs=idata_kwargs
)
loo_exact = az.reloo(exp_wrapper, loo_orig=loo_psis)
# Out:
# /home/oriol/venvs/arviz-dev/lib/python3.6/site-packages/arviz/stats/stats_refitting.py:98: UserWarning: reloo is an experimental and untested feature
#   warnings.warn("reloo is an experimental and untested feature", UserWarning)
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 0
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 0
# WARNING:pystan:134 of 8000 iterations ended with a divergence (1.68 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 1
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 1
# WARNING:pystan:9 of 8000 iterations ended with a divergence (0.113 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 2
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 2
# WARNING:pystan:46 of 8000 iterations ended with a divergence (0.575 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 3
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 3
# WARNING:pystan:11 of 8000 iterations ended with a divergence (0.138 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 4
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 4
# WARNING:pystan:116 of 8000 iterations ended with a divergence (1.45 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 5
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 5
# WARNING:pystan:9 of 8000 iterations ended with a divergence (0.113 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 6
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 6
# WARNING:pystan:11 of 8000 iterations ended with a divergence (0.138 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 7
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 7
# WARNING:pystan:68 of 8000 iterations ended with a divergence (0.85 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 8
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 8
# WARNING:pystan:116 of 8000 iterations ended with a divergence (1.45 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 9
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 9
# WARNING:pystan:17 of 8000 iterations ended with a divergence (0.212 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 10
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 10
# WARNING:pystan:73 of 8000 iterations ended with a divergence (0.912 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 11
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 11
# WARNING:pystan:28 of 8000 iterations ended with a divergence (0.35 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 12
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 12
# WARNING:pystan:10 of 8000 iterations ended with a divergence (0.125 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 13
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 13
# WARNING:pystan:10 of 8000 iterations ended with a divergence (0.125 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 14
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 14
# WARNING:pystan:11 of 8000 iterations ended with a divergence (0.138 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 15
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 15
# WARNING:pystan:1 of 8000 iterations ended with a divergence (0.0125 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 16
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 16
# WARNING:pystan:14 of 8000 iterations ended with a divergence (0.175 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 17
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 17
# WARNING:pystan:29 of 8000 iterations ended with a divergence (0.362 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 18
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 18
# WARNING:pystan:162 of 8000 iterations ended with a divergence (2.02 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 19
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 19
# WARNING:pystan:103 of 8000 iterations ended with a divergence (1.29 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 20
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 20
# WARNING:pystan:13 of 8000 iterations ended with a divergence (0.163 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 21
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 21
# WARNING:pystan:12 of 8000 iterations ended with a divergence (0.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 22
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 22
# WARNING:pystan:8 of 8000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 23
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 23
# WARNING:pystan:20 of 8000 iterations ended with a divergence (0.25 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 24
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 24
# WARNING:pystan:25 of 8000 iterations ended with a divergence (0.312 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 25
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 25
# WARNING:pystan:19 of 8000 iterations ended with a divergence (0.237 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 26
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 26
# WARNING:pystan:12 of 8000 iterations ended with a divergence (0.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 27
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 27
# WARNING:pystan:328 of 8000 iterations ended with a divergence (4.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 28
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 28
# WARNING:pystan:15 of 8000 iterations ended with a divergence (0.188 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 29
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 29
# WARNING:pystan:166 of 8000 iterations ended with a divergence (2.08 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 30
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 30
# WARNING:pystan:33 of 8000 iterations ended with a divergence (0.412 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 31
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 31
# WARNING:pystan:7 of 8000 iterations ended with a divergence (0.0875 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 32
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 32
# WARNING:pystan:7 of 8000 iterations ended with a divergence (0.0875 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 33
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 33
# WARNING:pystan:35 of 8000 iterations ended with a divergence (0.438 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 34
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 34
# WARNING:pystan:9 of 8000 iterations ended with a divergence (0.113 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 35
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 35
# WARNING:pystan:53 of 8000 iterations ended with a divergence (0.662 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 36
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 36
# WARNING:pystan:4 of 8000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 37
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 37
# WARNING:pystan:39 of 8000 iterations ended with a divergence (0.487 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 38
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 38
# WARNING:pystan:36 of 8000 iterations ended with a divergence (0.45 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 39
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 39
# WARNING:pystan:468 of 8000 iterations ended with a divergence (5.85 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 40
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 40
# WARNING:pystan:35 of 8000 iterations ended with a divergence (0.438 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 41
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 41
# WARNING:pystan:14 of 8000 iterations ended with a divergence (0.175 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 42
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 42
# WARNING:pystan:108 of 8000 iterations ended with a divergence (1.35 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 43
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 43
# WARNING:pystan:49 of 8000 iterations ended with a divergence (0.613 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 44
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 44
# WARNING:pystan:10 of 8000 iterations ended with a divergence (0.125 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 45
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 45
# WARNING:pystan:53 of 8000 iterations ended with a divergence (0.662 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 46
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 46
# WARNING:pystan:4 of 8000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 47
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 47
# WARNING:pystan:45 of 8000 iterations ended with a divergence (0.562 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 48
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 48
# WARNING:pystan:41 of 8000 iterations ended with a divergence (0.512 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 49
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 49
# WARNING:pystan:25 of 8000 iterations ended with a divergence (0.312 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 50
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 50
# WARNING:pystan:4 of 8000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 51
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 51
# WARNING:pystan:20 of 8000 iterations ended with a divergence (0.25 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 52
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 52
# WARNING:pystan:17 of 8000 iterations ended with a divergence (0.212 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 53
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 53
# WARNING:pystan:35 of 8000 iterations ended with a divergence (0.438 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 54
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 54
# WARNING:pystan:32 of 8000 iterations ended with a divergence (0.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 55
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 55
# WARNING:pystan:43 of 8000 iterations ended with a divergence (0.537 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 56
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 56
# WARNING:pystan:20 of 8000 iterations ended with a divergence (0.25 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 57
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 57
# WARNING:pystan:76 of 8000 iterations ended with a divergence (0.95 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 58
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 58
# WARNING:pystan:5 of 8000 iterations ended with a divergence (0.0625 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 59
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 59
# WARNING:pystan:90 of 8000 iterations ended with a divergence (1.12 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 60
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 60
# WARNING:pystan:134 of 8000 iterations ended with a divergence (1.68 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 61
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 61
# WARNING:pystan:37 of 8000 iterations ended with a divergence (0.463 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 62
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 62
# WARNING:pystan:240 of 8000 iterations ended with a divergence (3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 63
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 63
# WARNING:pystan:12 of 8000 iterations ended with a divergence (0.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 64
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 64
# WARNING:pystan:51 of 8000 iterations ended with a divergence (0.637 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 65
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 65
# WARNING:pystan:5 of 8000 iterations ended with a divergence (0.0625 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 66
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 66
# WARNING:pystan:2 of 8000 iterations ended with a divergence (0.025 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 67
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 67
# WARNING:pystan:33 of 8000 iterations ended with a divergence (0.412 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 68
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 68
# WARNING:pystan:319 of 8000 iterations ended with a divergence (3.99 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 69
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 69
# WARNING:pystan:10 of 8000 iterations ended with a divergence (0.125 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 70
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 70
# WARNING:pystan:38 of 8000 iterations ended with a divergence (0.475 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 71
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 71
# WARNING:pystan:90 of 8000 iterations ended with a divergence (1.12 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 72
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 72
# WARNING:pystan:8 of 8000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 73
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 73
# WARNING:pystan:30 of 8000 iterations ended with a divergence (0.375 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 74
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 74
# WARNING:pystan:4 of 8000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 75
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 75
# WARNING:pystan:24 of 8000 iterations ended with a divergence (0.3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 76
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 76
# WARNING:pystan:7 of 8000 iterations ended with a divergence (0.0875 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 77
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 77
# WARNING:pystan:352 of 8000 iterations ended with a divergence (4.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 78
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 78
# WARNING:pystan:31 of 8000 iterations ended with a divergence (0.388 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 79
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 79
# WARNING:pystan:20 of 8000 iterations ended with a divergence (0.25 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 80
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 80
# WARNING:pystan:41 of 8000 iterations ended with a divergence (0.512 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 81
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 81
# WARNING:pystan:6 of 8000 iterations ended with a divergence (0.075 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 82
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 82
# WARNING:pystan:36 of 8000 iterations ended with a divergence (0.45 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 83
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 83
# WARNING:pystan:58 of 8000 iterations ended with a divergence (0.725 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 84
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 84
# WARNING:pystan:2 of 8000 iterations ended with a divergence (0.025 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 85
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 85
# WARNING:pystan:13 of 8000 iterations ended with a divergence (0.163 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 86
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 86
# WARNING:pystan:6 of 8000 iterations ended with a divergence (0.075 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 87
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 87
# WARNING:pystan:146 of 8000 iterations ended with a divergence (1.82 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 88
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 88
# WARNING:pystan:30 of 8000 iterations ended with a divergence (0.375 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 89
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 89
# WARNING:pystan:19 of 8000 iterations ended with a divergence (0.237 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 90
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 90
# WARNING:pystan:26 of 8000 iterations ended with a divergence (0.325 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 91
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 91
# WARNING:pystan:21 of 8000 iterations ended with a divergence (0.263 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 92
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 92
# WARNING:pystan:16 of 8000 iterations ended with a divergence (0.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 93
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 93
# WARNING:pystan:105 of 8000 iterations ended with a divergence (1.31 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 94
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 94
# WARNING:pystan:89 of 8000 iterations ended with a divergence (1.11 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 95
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 95
# WARNING:pystan:160 of 8000 iterations ended with a divergence (2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 96
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 96
# WARNING:pystan:5 of 8000 iterations ended with a divergence (0.0625 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 97
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 97
# WARNING:pystan:172 of 8000 iterations ended with a divergence (2.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 98
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 98
# WARNING:pystan:19 of 8000 iterations ended with a divergence (0.237 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 99
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 99
# WARNING:pystan:54 of 8000 iterations ended with a divergence (0.675 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 100
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 100
# WARNING:pystan:122 of 8000 iterations ended with a divergence (1.52 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 101
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 101
# WARNING:pystan:25 of 8000 iterations ended with a divergence (0.312 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 102
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 102
# WARNING:pystan:9 of 8000 iterations ended with a divergence (0.113 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 103
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 103
# WARNING:pystan:54 of 8000 iterations ended with a divergence (0.675 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 104
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 104
# WARNING:pystan:4 of 8000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 105
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 105
# WARNING:pystan:6 of 8000 iterations ended with a divergence (0.075 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 106
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 106
# WARNING:pystan:81 of 8000 iterations ended with a divergence (1.01 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 107
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 107
# WARNING:pystan:17 of 8000 iterations ended with a divergence (0.212 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 108
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 108
# WARNING:pystan:13 of 8000 iterations ended with a divergence (0.163 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 109
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 109
# WARNING:pystan:39 of 8000 iterations ended with a divergence (0.487 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 110
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 110
# WARNING:pystan:8 of 8000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 111
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 111
# WARNING:pystan:119 of 8000 iterations ended with a divergence (1.49 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 112
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 112
# WARNING:pystan:266 of 8000 iterations ended with a divergence (3.33 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 113
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 113
# WARNING:pystan:393 of 8000 iterations ended with a divergence (4.91 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 114
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 114
# WARNING:pystan:13 of 8000 iterations ended with a divergence (0.163 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 115
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 115
# WARNING:pystan:21 of 8000 iterations ended with a divergence (0.263 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 116
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 116
# WARNING:pystan:26 of 8000 iterations ended with a divergence (0.325 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 117
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 117
# WARNING:pystan:144 of 8000 iterations ended with a divergence (1.8 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 118
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 118
# WARNING:pystan:20 of 8000 iterations ended with a divergence (0.25 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 119
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 119
# WARNING:pystan:216 of 8000 iterations ended with a divergence (2.7 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 120
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 120
# WARNING:pystan:49 of 8000 iterations ended with a divergence (0.613 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 121
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 121
# WARNING:pystan:64 of 8000 iterations ended with a divergence (0.8 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 122
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 122
# WARNING:pystan:7 of 8000 iterations ended with a divergence (0.0875 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 123
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 123
# WARNING:pystan:4 of 8000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 124
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 124
# WARNING:pystan:128 of 8000 iterations ended with a divergence (1.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 125
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 125
# WARNING:pystan:6 of 8000 iterations ended with a divergence (0.075 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 126
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 126
# WARNING:pystan:23 of 8000 iterations ended with a divergence (0.287 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 127
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 127
# WARNING:pystan:14 of 8000 iterations ended with a divergence (0.175 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 128
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 128
# WARNING:pystan:14 of 8000 iterations ended with a divergence (0.175 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 129
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 129
# WARNING:pystan:43 of 8000 iterations ended with a divergence (0.537 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 130
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 130
# WARNING:pystan:138 of 8000 iterations ended with a divergence (1.73 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 131
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 131
# WARNING:pystan:25 of 8000 iterations ended with a divergence (0.312 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 132
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 132
# WARNING:pystan:179 of 8000 iterations ended with a divergence (2.24 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 133
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 133
# WARNING:pystan:26 of 8000 iterations ended with a divergence (0.325 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 134
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 134
# WARNING:pystan:202 of 8000 iterations ended with a divergence (2.52 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 135
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 135
# WARNING:pystan:28 of 8000 iterations ended with a divergence (0.35 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 136
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 136
# WARNING:pystan:99 of 8000 iterations ended with a divergence (1.24 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 137
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 137
# WARNING:pystan:21 of 8000 iterations ended with a divergence (0.263 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 138
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 138
# WARNING:pystan:32 of 8000 iterations ended with a divergence (0.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 139
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 139
# WARNING:pystan:122 of 8000 iterations ended with a divergence (1.52 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 140
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 140
# WARNING:pystan:70 of 8000 iterations ended with a divergence (0.875 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 141
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 141
# WARNING:pystan:204 of 8000 iterations ended with a divergence (2.55 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 142
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 142
# WARNING:pystan:7 of 8000 iterations ended with a divergence (0.0875 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 143
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 143
# WARNING:pystan:8 of 8000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 144
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 144
# WARNING:pystan:9 of 8000 iterations ended with a divergence (0.113 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 145
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 145
# WARNING:pystan:90 of 8000 iterations ended with a divergence (1.12 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 146
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 146
# WARNING:pystan:22 of 8000 iterations ended with a divergence (0.275 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 147
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 147
# WARNING:pystan:5 of 8000 iterations ended with a divergence (0.0625 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 148
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 148
# WARNING:pystan:17 of 8000 iterations ended with a divergence (0.212 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 149
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 149
# WARNING:pystan:25 of 8000 iterations ended with a divergence (0.312 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 150
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 150
# WARNING:pystan:170 of 8000 iterations ended with a divergence (2.12 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 151
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 151
# WARNING:pystan:5 of 8000 iterations ended with a divergence (0.0625 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 152
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 152
# WARNING:pystan:17 of 8000 iterations ended with a divergence (0.212 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 153
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 153
# WARNING:pystan:67 of 8000 iterations ended with a divergence (0.838 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 154
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 154
# WARNING:pystan:6 of 8000 iterations ended with a divergence (0.075 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 155
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 155
# WARNING:pystan:6 of 8000 iterations ended with a divergence (0.075 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 156
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 156
# WARNING:pystan:106 of 8000 iterations ended with a divergence (1.32 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 157
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 157
# WARNING:pystan:8 of 8000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 158
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 158
# WARNING:pystan:14 of 8000 iterations ended with a divergence (0.175 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 159
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 159
# WARNING:pystan:19 of 8000 iterations ended with a divergence (0.237 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 160
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 160
# WARNING:pystan:16 of 8000 iterations ended with a divergence (0.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 161
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 161
# WARNING:pystan:3 of 8000 iterations ended with a divergence (0.0375 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 162
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 162
# WARNING:pystan:33 of 8000 iterations ended with a divergence (0.412 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 163
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 163
# WARNING:pystan:25 of 8000 iterations ended with a divergence (0.312 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 164
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 164
# WARNING:pystan:50 of 8000 iterations ended with a divergence (0.625 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 165
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 165
# WARNING:pystan:100 of 8000 iterations ended with a divergence (1.25 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 166
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 166
# WARNING:pystan:36 of 8000 iterations ended with a divergence (0.45 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 167
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 167
# WARNING:pystan:9 of 8000 iterations ended with a divergence (0.113 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 168
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 168
# WARNING:pystan:5 of 8000 iterations ended with a divergence (0.0625 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 169
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 169
# WARNING:pystan:13 of 8000 iterations ended with a divergence (0.163 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 170
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 170
# WARNING:pystan:63 of 8000 iterations ended with a divergence (0.787 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 171
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 171
# WARNING:pystan:8 of 8000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 172
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 172
# WARNING:pystan:24 of 8000 iterations ended with a divergence (0.3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 173
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 173
# WARNING:pystan:16 of 8000 iterations ended with a divergence (0.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 174
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 174
# WARNING:pystan:8 of 8000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 175
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 175
# WARNING:pystan:3 of 8000 iterations ended with a divergence (0.0375 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 176
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 176
# WARNING:pystan:22 of 8000 iterations ended with a divergence (0.275 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 177
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 177
# WARNING:pystan:51 of 8000 iterations ended with a divergence (0.637 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 178
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 178
# WARNING:pystan:42 of 8000 iterations ended with a divergence (0.525 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 179
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 179
# WARNING:pystan:236 of 8000 iterations ended with a divergence (2.95 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 180
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 180
# WARNING:pystan:60 of 8000 iterations ended with a divergence (0.75 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 181
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 181
# WARNING:pystan:239 of 8000 iterations ended with a divergence (2.99 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 182
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 182
# WARNING:pystan:8 of 8000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 183
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 183
# WARNING:pystan:10 of 8000 iterations ended with a divergence (0.125 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 184
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 184
# WARNING:pystan:236 of 8000 iterations ended with a divergence (2.95 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 185
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 185
# WARNING:pystan:63 of 8000 iterations ended with a divergence (0.787 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 186
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 186
# WARNING:pystan:76 of 8000 iterations ended with a divergence (0.95 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 187
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 187
# WARNING:pystan:41 of 8000 iterations ended with a divergence (0.512 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 188
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 188
# WARNING:pystan:33 of 8000 iterations ended with a divergence (0.412 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 189
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 189
# WARNING:pystan:13 of 8000 iterations ended with a divergence (0.163 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 190
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 190
# WARNING:pystan:41 of 8000 iterations ended with a divergence (0.512 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 191
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 191
# WARNING:pystan:278 of 8000 iterations ended with a divergence (3.48 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 192
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 192
# WARNING:pystan:12 of 8000 iterations ended with a divergence (0.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 193
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 193
# WARNING:pystan:5 of 8000 iterations ended with a divergence (0.0625 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 194
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 194
# WARNING:pystan:6 of 8000 iterations ended with a divergence (0.075 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 195
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 195
# WARNING:pystan:21 of 8000 iterations ended with a divergence (0.263 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 196
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 196
# WARNING:pystan:47 of 8000 iterations ended with a divergence (0.588 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 197
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 197
# WARNING:pystan:92 of 8000 iterations ended with a divergence (1.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 198
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 198
# WARNING:pystan:40 of 8000 iterations ended with a divergence (0.5 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.
# arviz.stats.stats_refitting - INFO - Refitting model excluding observation 199
# INFO:arviz.stats.stats_refitting:Refitting model excluding observation 199
# WARNING:pystan:311 of 8000 iterations ended with a divergence (3.89 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.9 to remove the divergences.

# %%
print("(exact) Leave one *subject* out cross validation (whole model)\n")
loo_exact
# Out:
# (exact) Leave one *subject* out cross validation (whole model)
# Computed from 8000 by 200 log-likelihood matrix
#
#          Estimate       SE
# elpd_loo  -296.89    10.86
# p_loo        3.80        -
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)      200  100.0%
#  (0.5, 0.7]   (ok)          0    0.0%
#    (0.7, 1]   (bad)         0    0.0%
#    (1, Inf)   (very bad)    0    0.0%
